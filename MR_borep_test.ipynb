# %%
from google.colab import drive
drive.mount('/content/drive/')

import sys
CUR_PATH = '/content/drive/My Drive/journal_club/randsent/'
sys.path.append(CUR_PATH)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import torch
import torch.nn as nn
import numpy as np

#import sys
#sys.path.insert(0, CUR_PATH)

import utils
from models import BOREP

import os

# %%
sys.path.insert(0, CUR_PATH + 'SentEval/')
import senteval

# %%
def prepare(params, samples):
    words = set([])
    for l in samples:
        for w in l:
            if w not in words:
                words.add(w)
    word2id = {w:i for i, w in enumerate(['<p>'] + list(words))}
    params.word2id = word2id
    params.lut = utils.load_vecs(params, word2id)
    return params


def batcher(params, batch):
    network = params['network']
    for n,i in enumerate(batch):
        if len(i) == 0:
            batch[n] = ['<p>']
    with torch.no_grad():
        vec = network.encode(batch, params)
    return vec

# %%
class Params():
    def __init__(self):
        self.n_folds = 5
        self.se_batch_size = 64
        self.gpu = True
        self.word_emb_file = CUR_PATH + 'glove.840B.300d.txt'
        self.word_emb_dim = 300
        self.input_dim = 300
        self.output_dim = 2048
        self.max_seq_len = 96
        self.init = 'uniform'
        self.pooling = 'mean'
        self.senteval_feat_dim = self.output_dim 
        
params = Params()

# %%
network = BOREP(params)

# %%
se = senteval.engine.SE({
    'task_path': os.path.join(CUR_PATH + '/SentEval/', 'data'),
    'word_emb_file': params.word_emb_file, 'word_emb_dim': params.word_emb_dim,
    'usepytorch': True, 'kfold': params.n_folds, 'feat_dim': params.senteval_feat_dim, 
    'seed': 111, 'batch_size': params.se_batch_size, 'network': network,
    'classifier': {'nhid': 0}
}, batcher, prepare)

# %%
# %%time

import warnings 
warnings.filterwarnings('ignore')

results = se.eval(['MR'])
# Out:
# CPU times: user 9min 2s, sys: 42.7 s, total: 9min 44s
# Wall time: 11min 25s

# %%
print('MR results:')
print('Accuracy train: {}  Accuracy test: {}'.format(results['MR']['devacc'], results['MR']['acc']))
# Out:
# MR results:
# Accuracy train: 77.28  Accuracy test: 76.51
